# %% [markdown]
# # 🚀 02 — Agents Learning Roadmap (Option A)
#
# A phase‑based roadmap for becoming an Agentic AI Engineer.
#
# ## Phase 0 — Foundations
# - LLM basics
# - Prompting patterns
# - Intro to CoT & ReAct
#
# ## Phase 1 — Agent Fundamentals
# - What is an agent?
# - Agent loop: Think → Act → Observe
# - Tool schemas
#
# ## Phase 2 — Tool‑Using Agents
# - Designing tools
# - Action/Observation patterns
# - Error handling
#
# ## Phase 3 — Memory & Planning
# - Short vs long-term memory
# - Planning loops
# - Reflection loops
#
# ## Phase 4 — Multi‑Agent Systems
# - Supervisor/worker
# - Debate agents
# - Message routing
#
# ## Phase 5 — Agentic RAG
# - Retrieval planning
# - Query rewriting
# - Multi-hop reasoning
#
# ## Phase 6 — Agents + MCP
# - MCP as capability layer
# - Safe tool use
# - Full workflows
#
# ## Phase 7 — Production Engineering
# - Observability
# - Safety policies
# - Cost control
# - Reliability
#
# ## Milestones
# - Build your first ReAct agent
# - Build planner-executor
# - Build multi-agent pipeline
# - Build Agentic RAG chatbot
# - Build MCP-enabled agent system
#
# ## Notebook Sequence
# 1. TOC
# 2. Roadmap (this file)
# 3. Deep Dive Concepts
# 4. Hands-On Python
# 5. Hands-On Node
# 6. Patterns Library
# 7. Projects Lab
# 8. Agentic RAG
# 9. MCP with Agents
# 10. Full RAG + Agents + MCP
