# %% [markdown]
# # 📘 01 — Agents & Agentic AI Universe
# ## **Complete Table of Contents (Option A Edition)**
#
# # PART I — Foundations
# ## 1. What Are Agents?
# ## 2. Agent Architectures
# ## 3. Reasoning Models
#
# # PART II — Capabilities
# ## 4. Tool Use
# ## 5. Memory Systems
# ## 6. Planning
#
# # PART III — Patterns & Loops
# ## 7. Agentic Patterns
# ## 8. Agent Loops
#
# # PART IV — Multi-Agent Systems
# ## 9. Multi-Agent Architectures
# ## 10. Communication Protocols
#
# # PART V — Integrations
# ## 11. Agents + RAG
# ## 12. Agents + MCP
# ## 13. Full RAG + Agents + MCP
#
# # PART VI — Engineering
# ## 14. Agents in Python
# ## 15. Agents in Node.js
# ## 16. Agentic Patterns Library
#
# # PART VII — Projects
# ## 17. Real-World Projects
# ## 18. Multi-Agent Applications
#
# # PART VIII — Safety & Evaluation
# ## 19. Agent Safety
# ## 20. Evaluation
#
# # PART IX — References
# ## 21. Frameworks
# ## 22. Research Papers
